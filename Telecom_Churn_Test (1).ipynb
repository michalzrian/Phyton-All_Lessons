# %% [markdown]
# #### 1. Dataframe basics

# %% [markdown]
# #### 1.1. Import pandas and reffered the package as pd + Load "telecom_churn.csv" and assign in to the variable df <span style= color:#0033cc>(3 points)</span>

# %%
pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("telecom_churn.csv")
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1  False
# 1                          1  False
# 2                          0  False
# 3                          2  False
# 4                          3  False
# ...                      ...    ...
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False
#
# [3333 rows x 20 columns]

# %% [markdown]
# #### 1.2 Return the column labels/names <span style= color:#0033cc>(2 points)</span>

# %%
print(df.columns)
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# #### 1.3 Print the df shape <span style= color:#0033cc>(3 points)</span>

# %%
print(df.shape)
# Out:
# (3333, 20)

# %% [markdown]
# #### 2. What is the total day calls given by state and area code?

# %% [markdown]
# #### 2.1 Group the df by state and area code (assign it to grouped variable). <span style= color:#0033cc>(5 points)</span>

# %%
gk = df.groupby(['State', 'Area code'])
gk

# %% [markdown]
# #### 2.2 Use agg with the desired function sum to get the final answer (assign it to telecom_agg variable).<span style= color:#0033cc>(5 points)</span>

# %%
telecom_agg = gk.agg('sum')
telecom_agg
# Out:
#                  Account length  \
# State Area code
# AK    408                  1116
#       415                  2532
#       510                  1406
# AL    408                  2454
#       415                  3828
# ...                         ...
# WV    415                  5142
#       510                  3133
# WY    408                  1598
#       415                  4401
#       510                  2143
#
#                                                 International plan  \
# State Area code
# AK    408                             NoNoNoNoNoNoNoNoNoNoNoNoNoNo
#       415        YesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoN...
#       510                           NoNoNoNoYesNoNoYesNoNoNoNoNoNo
# AL    408        NoNoNoYesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoN...
#       415        NoNoNoNoNoYesNoNoNoNoNoNoNoNoNoNoYesNoNoYesNoN...
# ...                                                            ...
# WV    415        YesNoNoNoNoNoNoNoNoYesNoNoNoNoNoNoNoNoYesNoNoN...
#       510        NoYesNoNoNoNoYesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# WY    408                      NoNoNoNoNoNoNoNoNoNoNoYesNoNoNoNoNo
#       415        NoNoYesNoNoNoNoNoNoNoNoYesNoNoNoYesNoYesNoNoNo...
#       510                NoNoNoNoNoNoYesNoYesNoNoNoNoYesNoNoNoNoNo
#
#                                                    Voice mail plan  \
# State Area code
# AK    408                         YesNoNoNoNoNoNoYesNoNoNoYesNoYes
#       415        YesNoYesNoNoNoNoNoYesNoNoYesYesNoNoYesYesYesNo...
#       510                           YesNoNoNoNoNoNoYesNoNoNoNoNoNo
# AL    408        NoYesNoYesYesNoNoNoNoNoNoYesNoYesNoNoNoNoNoYes...
#       415        NoNoYesYesNoNoNoNoYesYesNoNoNoYesNoNoNoNoNoNoN...
# ...                                                            ...
# WV    415        YesNoNoNoNoNoNoNoYesNoNoNoYesYesYesYesNoNoYesN...
#       510        NoYesYesYesNoNoNoYesNoNoNoYesYesNoNoYesNoNoNoN...
# WY    408                  YesYesNoNoNoYesYesYesNoNoNoNoNoNoNoNoNo
#       415        YesNoNoNoYesNoNoYesNoNoNoNoNoNoNoYesYesYesYesN...
#       510                NoNoNoNoNoNoNoYesNoNoNoNoNoNoYesYesNoNoNo
#
#                  Number vmail messages  Total day minutes  Total day calls  \
# State Area code
# AK    408                          132             2435.8             1342
#       415                          291             4468.7             2357
#       510                           48             2371.5             1255
# AL    408                          214             4751.2             2524
#       415                          261             7336.9             4090
# ...                                ...                ...              ...
# WV    415                          382             9046.1             5474
#       510                          384             5719.7             3491
# WY    408                          187             2882.1             1659
#       415                          263             7410.3             4205
#       510                           52             3580.7             2007
#
#                  Total day charge  Total eve minutes  Total eve calls  \
# State Area code
# AK    408                  414.09             2416.8             1376
#       415                  759.69             4299.7             2306
#       510                  403.16             2866.2             1340
# AL    408                  807.69             4746.2             2513
#       415                 1247.27             7957.0             3962
# ...                           ...                ...              ...
# WV    415                 1537.86             9461.4             5111
#       510                  972.39             6607.1             3480
# WY    408                  489.95             3537.6             1699
#       415                 1259.76             8460.7             4030
#       510                  608.72             3850.5             1912
#
#                  Total eve charge  Total night minutes  Total night calls  \
# State Area code
# AK    408                  205.43               2547.1               1411
#       415                  365.48               4568.3               2321
#       510                  243.63               2885.6               1330
# AL    408                  403.42               4567.5               2367
#       415                  676.36               7593.1               3917
# ...                           ...                  ...                ...
# WV    415                  804.19              10773.8               5349
#       510                  561.59               6777.1               3307
# WY    408                  300.69               3213.8               1658
#       415                  719.15               8232.9               4291
#       510                  327.30               3889.2               1907
#
#                  Total night charge  Total intl minutes  Total intl calls  \
# State Area code
# AK    408                    114.61               142.6                58
#       415                    205.59               225.9               119
#       510                    129.85               152.5                73
# AL    408                    205.53               274.2               109
#       415                    341.70               393.6               194
# ...                             ...                 ...               ...
# WV    415                    484.85               553.4               242
#       510                    304.98               315.3               138
# WY    408                    144.61               175.7                95
#       415                    370.47               417.3               185
#       510                    175.04               207.3               103
#
#                  Total intl charge  Customer service calls  Churn
# State Area code
# AK    408                    38.53                      15      0
#       415                    60.98                      38      3
#       510                    41.17                      28      0
# AL    408                    74.05                      32      4
#       415                   106.26                      71      3
# ...                            ...                     ...    ...
# WV    415                   149.45                      79      3
#       510                    85.16                      54      6
# WY    408                    47.46                      17      0
#       415                   112.67                      65      5
#       510                    55.99                      29      4
#
# [153 rows x 18 columns]

# %% [markdown]
# #### 2.3 Reset the group by index <span style= color:#0033cc>(3 points)</span>

# %%
df.reset_index(inplace=True)

# %% [markdown]
# #### 2.4 Use head function to review the first 10 telecom_agg rows <span style= color:#0033cc>(3 points)</span>

# %%
telecom_agg.head(10)
# Out:
#                  Account length  \
# State Area code
# AK    408                  1116
#       415                  2532
#       510                  1406
# AL    408                  2454
#       415                  3828
#       510                  1560
# AR    408                  1289
#       415                  2684
#       510                  1361
# AZ    408                  1384
#
#                                                 International plan  \
# State Area code
# AK    408                             NoNoNoNoNoNoNoNoNoNoNoNoNoNo
#       415        YesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoN...
#       510                           NoNoNoNoYesNoNoYesNoNoNoNoNoNo
# AL    408        NoNoNoYesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoN...
#       415        NoNoNoNoNoYesNoNoNoNoNoNoNoNoNoNoYesNoNoYesNoN...
#       510                         YesYesNoNoNoNoNoNoNoNoNoNoNoNoNo
# AR    408                              NoNoNoNoYesNoNoNoNoNoNoNoNo
#       415        NoNoYesNoNoNoNoNoNoYesNoNoNoNoNoNoNoNoNoYesYes...
#       510                          NoNoNoNoNoNoNoNoYesNoNoNoNoNoNo
# AZ    408                           NoNoNoNoNoNoNoNoNoNoNoNoNoNoNo
#
#                                                    Voice mail plan  \
# State Area code
# AK    408                         YesNoNoNoNoNoNoYesNoNoNoYesNoYes
#       415        YesNoYesNoNoNoNoNoYesNoNoYesYesNoNoYesYesYesNo...
#       510                           YesNoNoNoNoNoNoYesNoNoNoNoNoNo
# AL    408        NoYesNoYesYesNoNoNoNoNoNoYesNoYesNoNoNoNoNoYes...
#       415        NoNoYesYesNoNoNoNoYesYesNoNoNoYesNoNoNoNoNoNoN...
#       510                       NoNoNoNoYesYesNoNoYesNoNoNoNoYesNo
# AR    408                              NoNoNoNoNoYesNoNoNoNoNoNoNo
#       415        NoNoYesYesNoNoYesNoYesNoNoYesYesNoNoNoNoYesYes...
#       510                       NoYesYesNoNoNoNoYesNoNoNoYesNoNoNo
# AZ    408                       NoNoNoYesYesNoNoNoNoNoNoNoYesNoYes
#
#                  Number vmail messages  Total day minutes  Total day calls  \
# State Area code
# AK    408                          132             2435.8             1342
#       415                          291             4468.7             2357
#       510                           48             2371.5             1255
# AL    408                          214             4751.2             2524
#       415                          261             7336.9             4090
#       510                           99             2792.7             1314
# AR    408                           16             2187.3             1382
#       415                          248             4843.1             2756
#       510                          132             2656.0             1480
# AZ    408                          136             2695.3             1452
#
#                  Total day charge  Total eve minutes  Total eve calls  \
# State Area code
# AK    408                  414.09             2416.8             1376
#       415                  759.69             4299.7             2306
#       510                  403.16             2866.2             1340
# AL    408                  807.69             4746.2             2513
#       415                 1247.27             7957.0             3962
#       510                  474.76             2933.8             1402
# AR    408                  371.83             2475.3             1421
#       415                  823.32             5444.2             2597
#       510                  451.55             3138.1             1363
# AZ    408                  458.20             2888.6             1538
#
#                  Total eve charge  Total night minutes  Total night calls  \
# State Area code
# AK    408                  205.43               2547.1               1411
#       415                  365.48               4568.3               2321
#       510                  243.63               2885.6               1330
# AL    408                  403.42               4567.5               2367
#       415                  676.36               7593.1               3917
#       510                  249.38               2822.2               1605
# AR    408                  210.41               2760.6               1185
#       415                  462.78               5283.7               2750
#       510                  266.74               3255.7               1513
# AZ    408                  245.52               3252.2               1580
#
#                  Total night charge  Total intl minutes  Total intl calls  \
# State Area code
# AK    408                    114.61               142.6                58
#       415                    205.59               225.9               119
#       510                    129.85               152.5                73
# AL    408                    205.53               274.2               109
#       415                    341.70               393.6               194
#       510                    127.00               155.6                73
# AR    408                    124.24               142.1                62
#       415                    237.78               277.8               119
#       510                    146.50               150.6                77
# AZ    408                    146.36               160.7                56
#
#                  Total intl charge  Customer service calls  Churn
# State Area code
# AK    408                    38.53                      15      0
#       415                    60.98                      38      3
#       510                    41.17                      28      0
# AL    408                    74.05                      32      4
#       415                   106.26                      71      3
#       510                    42.01                      22      1
# AR    408                    38.36                      19      1
#       415                    75.02                      66      9
#       510                    40.66                      24      1
# AZ    408                    43.40                      27      1

# %% [markdown]
# #### 3. Users Churn rate

# %% [markdown]
# #### 3.1 Change "Churn" column type to an integer: <span style= color:#0033cc>(3 points)</span>

# %%
df = df.astype({"Churn": int})
df.head(1)
# Out:
#    index State  Account length  Area code International plan Voice mail plan  \
# 0      0    KS             128        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
#
#    Total day charge  ...  Total eve calls  Total eve charge  \
# 0             45.07  ...               99             16.78
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
#
#    Customer service calls  Churn
# 0                       1      0
#
# [1 rows x 21 columns]

# %% [markdown]
# #### 3.2 what is the users "churn rate" in our dataframe? <span style= color:#0033cc>(5 points)</span>
# Hint: the churn rate formula can be calculated as the "number of churned" divided by the "total number of customers".

# %%
sumOfChurned = sum(df['Churn'])
sumOfCustomers = df.shape[0]
theSum = sumOfChurned/sumOfCustomers
theSum
# Out:
# 0.14491449144914492

# %% [markdown]
# #### 3.3  How the charn rate can affect on the company? <span style= color:#0033cc>(3 points)</span>

# %% [markdown]
# #### 3.4 How much time (on average) do churned users spend on the phone during daytime? <span style= color:#0033cc>(5 points)</span>
# Hint: filter churn column when the value of churn equal to 1

# %%
mean = df.loc[df['Churn'] == 1, 'Total eve minutes'].mean()
mean
# Out:
# 212.41014492753624

# %% [markdown]
# #### 3.5 What is the maximum length of international calls among loyal users who do not have an international plan? ('International plan' == 'No') <span style= color:#0033cc>(5 points)</span>
# Hint: 2 filters conditions,churn equal to 0 and international plan equal to no

# %%
maxinternational = df.loc[(df['Churn'] == 1) & (df['International plan'] == 'No'), 'Total day minutes'].max()
maxinternational
# Out:
# 350.8

# %% [markdown]
# #### 4. Select top 3 international plan subscribers and non subscribers with the most intl calls

# %% [markdown]
# #### 4.1. Build a function top which attributes df, n (for the top n) and column. In this function use sort_values to sort the values in the column specified. <span style= color:#0033cc>(10 points)</span>
# Note: Do not apply the function on the whole data frame (e.i. top(df, n=3)) as the output will be the top 3 regardless of subscribers and non-subscribers.

# %%
def top(df, n, column):
    sorted_df = df.sort_values(by=column, ascending=False) 
    return sorted_df.head(n)

# %% [markdown]
# #### 4.2. Group the df dataframe by 'International plan' and use apply(top) to apply this function. <span style= color:#0033cc>(5 points)</span>

# %%
functop = top(df,int(df['Total day minutes'].sum()),'Total day minutes')
functop
# Out:
#       index State  Account length  Area code International plan  \
# 365     365    CO             154        415                 No
# 985     985    NY              64        415                Yes
# 2594   2594    OH             115        510                Yes
# 156     156    OH              83        415                 No
# 605     605    MO             112        415                 No
# ...     ...   ...             ...        ...                ...
# 1986   1986    WI              70        415                 No
# 2753   2753    OH             134        415                 No
# 2736   2736    OK             127        510                 No
# 1397   1397    VT             101        510                 No
# 1345   1345    SD              98        415                 No
#
#      Voice mail plan  Number vmail messages  Total day minutes  \
# 365               No                      0              350.8
# 985               No                      0              346.8
# 2594              No                      0              345.3
# 156               No                      0              337.4
# 605               No                      0              335.5
# ...              ...                    ...                ...
# 1986              No                      0                7.9
# 2753              No                      0                7.8
# 2736             Yes                     27                2.6
# 1397              No                      0                0.0
# 1345              No                      0                0.0
#
#       Total day calls  Total day charge  ...  Total eve calls  \
# 365                75             59.64  ...               94
# 985                55             58.96  ...               79
# 2594               81             58.70  ...              106
# 156               120             57.36  ...              116
# 605                77             57.04  ...              109
# ...               ...               ...  ...              ...
# 1986              100              1.34  ...               83
# 2753               86              1.33  ...              100
# 2736              113              0.44  ...              102
# 1397                0              0.00  ...              119
# 1345                0              0.00  ...              130
#
#       Total eve charge  Total night minutes  Total night calls  \
# 365              18.40                253.9                100
# 985              21.21                275.4                102
# 2594             17.29                217.5                107
# 156              19.33                153.9                114
# 605              18.06                265.0                132
# ...                ...                  ...                ...
# 1986             11.59                156.6                 89
# 2753             14.57                186.5                 80
# 2736             21.59                242.7                156
# 1397             16.33                168.8                 95
# 1345             13.57                167.1                 88
#
#       Total night charge  Total intl minutes  Total intl calls  \
# 365                11.43                10.1                 9
# 985                12.39                13.3                 9
# 2594                9.79                11.8                 8
# 156                 6.93                15.8                 7
# 605                11.93                12.7                 8
# ...                  ...                 ...               ...
# 1986                7.05                12.1                 1
# 2753                8.39                12.9                 2
# 2736               10.92                 9.2                 5
# 1397                7.60                 7.2                 4
# 1345                7.52                 6.8                 1
#
#       Total intl charge  Customer service calls  Churn
# 365                2.73                       1      1
# 985                3.59                       1      1
# 2594               3.19                       1      1
# 156                4.27                       0      1
# 605                3.43                       2      1
# ...                 ...                     ...    ...
# 1986               3.27                       0      0
# 2753               3.48                       2      0
# 2736               2.48                       3      0
# 1397               1.94                       1      0
# 1345               1.84                       4      1
#
# [3333 rows x 21 columns]

# %% [markdown]
# #### 5. pd.crosstab

# %% [markdown]
# #### 5.1 how the observations in our sample are normalized (divide each value by the sum of the values) in the context of two variables - Churn and Voice mail plan. To do so, build a contingency table using the crosstab method. <span style= color:#0033cc>(6 points)</span>
# Hint: To normalize using all values, simply set normalize=True

# %%
ctable = pd.crosstab(df['Churn'], df['Voice mail plan'], normalize=True)
print(ctable)
# Out:
# Voice mail plan        No       Yes
# Churn
# 0                0.602460  0.252625
# 1                0.120912  0.024002

# %% [markdown]
# #### 5.2 What is the conclustion of most of users regarding voice mail usage? <span style= color:#0033cc>(4 points)</span>

# %% [markdown]
# #### 6. Columns calculations

# %% [markdown]
# #### 6.1 Add a column name 'total_charge', and get the total charge by sum all the charge columns <span style= color:#0033cc>(7 points)</span>

# %%
df.insert(3, 'total_charge', df['Total intl charge'].sum())
df
# Out:
#       index State  Account length  total_charge  Area code International plan  \
# 0         0    KS             128       9214.35        415                 No
# 1         1    OH             107       9214.35        415                 No
# 2         2    NJ             137       9214.35        415                 No
# 3         3    OH              84       9214.35        408                Yes
# 4         4    OK              75       9214.35        415                Yes
# ...     ...   ...             ...           ...        ...                ...
# 3328   3328    AZ             192       9214.35        415                 No
# 3329   3329    WV              68       9214.35        415                 No
# 3330   3330    RI              28       9214.35        510                 No
# 3331   3331    CT             184       9214.35        510                Yes
# 3332   3332    TN              74       9214.35        415                 No
#
#      Voice mail plan  Number vmail messages  Total day minutes  \
# 0                Yes                     25              265.1
# 1                Yes                     26              161.6
# 2                 No                      0              243.4
# 3                 No                      0              299.4
# 4                 No                      0              166.7
# ...              ...                    ...                ...
# 3328             Yes                     36              156.2
# 3329              No                      0              231.1
# 3330              No                      0              180.8
# 3331              No                      0              213.8
# 3332             Yes                     25              234.4
#
#       Total day calls  ...  Total eve calls  Total eve charge  \
# 0                 110  ...               99             16.78
# 1                 123  ...              103             16.62
# 2                 114  ...              110             10.30
# 3                  71  ...               88              5.26
# 4                 113  ...              122             12.61
# ...               ...  ...              ...               ...
# 3328               77  ...              126             18.32
# 3329               57  ...               55             13.04
# 3330              109  ...               58             24.55
# 3331              105  ...               84             13.57
# 3332              113  ...               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1      0
# 1                          1      0
# 2                          0      0
# 3                          2      0
# 4                          3      0
# ...                      ...    ...
# 3328                       2      0
# 3329                       3      0
# 3330                       2      0
# 3331                       2      0
# 3332                       0      0
#
# [3333 rows x 22 columns]

# %% [markdown]
# ####  6.2 Add a column name 'Day_charge_pct', and get day charge precentage of total charge by dividing the column 'Total day charge' by the column 'total_charge'. <span style= color:#0033cc>(7 points)</span>

# %%
df.insert(1, 'Day_charge_pct', df['Total day charge']/df['total_charge'])
df
# Out:
#       index  Day_charge_pct State  Account length  total_charge  Area code  \
# 0         0        0.004891    KS             128       9214.35        415
# 1         1        0.002981    OH             107       9214.35        415
# 2         2        0.004491    NJ             137       9214.35        415
# 3         3        0.005524    OH              84       9214.35        408
# 4         4        0.003076    OK              75       9214.35        415
# ...     ...             ...   ...             ...           ...        ...
# 3328   3328        0.002881    AZ             192       9214.35        415
# 3329   3329        0.004264    WV              68       9214.35        415
# 3330   3330        0.003336    RI              28       9214.35        510
# 3331   3331        0.003945    CT             184       9214.35        510
# 3332   3332        0.004325    TN              74       9214.35        415
#
#      International plan Voice mail plan  Number vmail messages  \
# 0                    No             Yes                     25
# 1                    No             Yes                     26
# 2                    No              No                      0
# 3                   Yes              No                      0
# 4                   Yes              No                      0
# ...                 ...             ...                    ...
# 3328                 No             Yes                     36
# 3329                 No              No                      0
# 3330                 No              No                      0
# 3331                Yes              No                      0
# 3332                 No             Yes                     25
#
#       Total day minutes  ...  Total eve calls  Total eve charge  \
# 0                 265.1  ...               99             16.78
# 1                 161.6  ...              103             16.62
# 2                 243.4  ...              110             10.30
# 3                 299.4  ...               88              5.26
# 4                 166.7  ...              122             12.61
# ...                 ...  ...              ...               ...
# 3328              156.2  ...              126             18.32
# 3329              231.1  ...               55             13.04
# 3330              180.8  ...               58             24.55
# 3331              213.8  ...               84             13.57
# 3332              234.4  ...               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1      0
# 1                          1      0
# 2                          0      0
# 3                          2      0
# 4                          3      0
# ...                      ...    ...
# 3328                       2      0
# 3329                       3      0
# 3330                       2      0
# 3331                       2      0
# 3332                       0      0
#
# [3333 rows x 23 columns]

# %% [markdown]
# #### 7. Day charge percentage and state visualization

# %% [markdown]
# #### 7.1 Import matplotlib.pyplot and referred the package as plt <span style= color:#0033cc>(2 points)</span>

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### 7.2 create new string list with the name 'my_color' that contains the following colors names: red,green,orange,blue,yellow <span style= color:#0033cc>(4 points)</span>

# %%
my_color = ['red', 'green', 'orange', 'blue', 'yellow']
my_color
# Out:
# ['red', 'green', 'orange', 'blue', 'yellow']

# %% [markdown]
# #### 7.3 Bar chart plot <span style= color:#0033cc>(10 points)</span>

# %% [markdown]
# 1.Select first 5 rows of the dataframe (use df.iloc[])

# %% [markdown]
# 2.Use <span style= color:blue>df.plot</span> function with kind='bar' and x='State' and y='Day_charge_pct' and color = my_colors to make a simple bar chart plot (of the day chart %).

# %% [markdown]
# 3.Use <span style= color:blue>plt.xlabel("State Code")</span> and <span style= color:blue>plt.ylabel("Day Charge %")</span> to label the corresponding axes

# %%
df.iloc[:5]
# Out:
#    index  Day_charge_pct State  Account length  total_charge  Area code  \
# 0      0        0.004891    KS             128       9214.35        415
# 1      1        0.002981    OH             107       9214.35        415
# 2      2        0.004491    NJ             137       9214.35        415
# 3      3        0.005524    OH              84       9214.35        408
# 4      4        0.003076    OK              75       9214.35        415
#
#   International plan Voice mail plan  Number vmail messages  \
# 0                 No             Yes                     25
# 1                 No             Yes                     26
# 2                 No              No                      0
# 3                Yes              No                      0
# 4                Yes              No                      0
#
#    Total day minutes  ...  Total eve calls  Total eve charge  \
# 0              265.1  ...               99             16.78
# 1              161.6  ...              103             16.62
# 2              243.4  ...              110             10.30
# 3              299.4  ...               88              5.26
# 4              166.7  ...              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1      0
# 1                       1      0
# 2                       0      0
# 3                       2      0
# 4                       3      0
#
# [5 rows x 23 columns]

# %%
df.plot(kind='bar', x='State', y='Day_charge_pct', color=my_color)
plt.show()

# %%
plt.xlabel('State Code')
plt.ylabel('Day Charge %')
plt.show()
